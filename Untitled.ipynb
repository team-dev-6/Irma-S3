# %%
import mysql
import mysql.connector

# %%
mydb = mysql.connector.connect(user = 'root', password = 'zanegabriels100',
                               host = '127.0.0.1',database='sprint3db')
cursor = mydb.cursor()
cursor.execute("ALTER TABLE DataSprint3 ADD Barcode VARCHAR(10) NOT NULL")

# %%
mycursor = mydb.cursor()
sql = "UPDATE DataSprint3 SET Barcode = '7859425' WHERE Brands = 'Tomato'" 
mycursor.execute(sql)
mydb.commit()
print(mycursor.rowcount, "record(s) affected")
# Out:
# 1 record(s) affected

# %%
mydb = mysql.connector.connect(user = 'root', password = 'zanegabriels100',
                               host = '127.0.0.1',database='sprint3db')
mycursor = mydb.cursor()

sql = "INSERT INTO DataSprint3 (Brands, `Cost Price`, Prices, Barcode) VALUES (%s, %s, %s,%s)"
val = ("Carrots", "5", 10,"1234")
mycursor.execute(sql, val)

mydb.commit()

print(mycursor.rowcount, "record inserted.")
# Out:
# 1 record inserted.

# %%
mycursor = mydb.cursor()

sql = "UPDATE DataSprint3 SET barcode = 1501234 WHERE brands = 'carrots'"

mycursor.execute(sql)

mydb.commit()

print(mycursor.rowcount, "record(s) affected")
# Out:
# 1 record(s) affected

# %%
import pandas as pd
df = pd.read_sql_query("SELECT * From DataSprint3 WHERE Catergories = 'Chips'", mydb)
df
# Out:
#    Labels Catergories        Brands  Cost Price  Prices  Stock  \
# 0       1       Chips    Simba 125g           8      16     50
# 1       2       Chips     Lays 125g           9      18     50
# 2       3       Chips  Doritos 125g           8      16     50
#
#    Brands Sold for Month  Profit  Barcode
# 0                     45     384  1000456
# 1                     50     450  1000457
# 2                     48     384  1000458

# %%
df = pd.read_sql_query("SELECT * From DataSprint3 WHERE Catergories = 'Cooldrink'", mydb)
df
# Out:
#    Labels Catergories      Brands  Cost Price  Prices  Stock  \
# 0       4   Cooldrink    Coke 2lt          10      20    100
# 1       5   Cooldrink   Fanta 2lt           9      18    100
# 2       6   Cooldrink  Sprite 2lt           9      18    100
#
#    Brands Sold for Month  Profit  Barcode
# 0                    100    1000  1212133
# 1                     90     810  1212134
# 2                     98     882  1212135

# %%
df = pd.read_sql_query("SELECT * From DataSprint3 WHERE Catergories = 'Chocolates'", mydb)
df
# Out:
#    Labels Catergories       Brands  Cost Price  Prices  Stock  \
# 0       7  Chocolates  Cadbury 50g           5      10     50
# 1       8  Chocolates      Tex 50g           5      10     50
# 2       9  Chocolates       PS 50g           5      10     50
#
#    Brands Sold for Month  Profit  Barcode
# 0                     48     192  9977881
# 1                     50     250  9977882
# 2                     38     190  9977883

# %%
df = pd.read_sql_query("SELECT * From DataSprint3 WHERE Catergories = 'Pies'", mydb)
df
# Out:
#    Labels Catergories          Brands  Cost Price  Prices  Stock  \
# 0      10        Pies    Pepper Steak          10      20     40
# 1      11        Pies         Chicken           8      16     40
# 2      12        Pies  Steak & Kidney          10      20     40
#
#    Brands Sold for Month  Profit  Barcode
# 0                     39     390  4745152
# 1                     30     240  4745153
# 2                     40     400  4745154

# %%
df = pd.read_sql_query("SELECT * From DataSprint3 WHERE Catergories = 'Fruit'", mydb)
df
# Out:
#    Labels Catergories  Brands  Cost Price  Prices  Stock  \
# 0      13       Fruit    Pear           6      12     50
# 1      14       Fruit   Apple           6      12     50
# 2      15       Fruit  Orange           5      10     50
#
#    Brands Sold for Month  Profit  Barcode
# 0                     45     270  1111119
# 1                     40     240  1111118
# 2                     39     195  1111117

# %%
df = pd.read_sql_query("SELECT * From DataSprint3 WHERE Catergories = 'Cupcakes'", mydb)
df
# Out:
#    Labels Catergories         Brands  Cost Price  Prices  Stock  \
# 0      16    Cupcakes  Chocolate (6)           9      18    100
# 1      17    Cupcakes    Vanilla (6)           7      14    100
# 2      18    Cupcakes  Blueberry (6)          10      20    100
#
#    Brands Sold for Month  Profit  Barcode
# 0                     95    1710  1238542
# 1                     80     560  1238543
# 2                    100    1000  1238544

# %%
import pandas as pd
import mysql
import mysql.connector
mydb = mysql.connector.connect(user = 'root', password = 'zanegabriels100',
                               host = '127.0.0.1',database='sprint3db')

df = pd.read_sql_query("SELECT * From DataSprint3 WHERE Catergories = 'Veg'", mydb)
df
alter = df.to_csv('Veg.csv', index = False)
new = pd.read_csv('Veg.csv')
new
# Out:
#    Labels Catergories   Brands  Cost Price  Prices  Stock  \
# 0      19         Veg  Spinach           8      16     30
# 1      20         Veg  Cabbage           8      16     30
# 2      21         Veg   Tomato           5      10     30
#
#    Brands Sold for Month  Profit  Barcode
# 0                     25     200  7859423
# 1                     30     240  7859424
# 2                     30     150  7859425

# %%
mycursor =mydb.cursor()
sql = "DELETE FROM datasprint3 WHERE barcode = '587252'"
mycursor.execute(sql)
mydb.commit()
print(mycursor.rowcount,"records deleted")
# Out:
# 1 records deleted
